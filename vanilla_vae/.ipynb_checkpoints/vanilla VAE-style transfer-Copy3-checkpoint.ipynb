# %%
# Incorporate point-correlation
def correlation_fun(x,input_dim,Rad):
    point_corr=0
    for i in range(input_dim):
        for j in range(input_dim):
            point_corr_temp1=tf.multiply(x[0][i,j],x[0][i,tf.mod(j+Rad,input_dim)])
            point_corr=tf.add(point_corr_temp1,point_corr)
    
    for i in range(input_dim):
        for j in range(input_dim):           
            point_corr_temp2=tf.multiply(x[0][i,j],x[0][tf.mod(i+Rad,input_dim),j])
            point_corr=tf.add(point_corr_temp2,point_corr)
    return (point_corr+2*input_dim**2)/4./input_dim**2

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import scipy.io as sio
# from torch.autograd import Variable
from tensorflow.examples.tutorials.mnist import input_data



# mnist = input_data.read_data_sets('../../MNIST_data', one_hot=True)
images = np.array(sio.loadmat('WB_test64_GAN_sm2.mat')['WB_sm'],dtype='float32')
images[images==0]=-1
# images=images[0:10]

mb_size = 5
z_dim = 8
X_dim = images.shape[1]
width = 32
hight = 32
h_dim = width/4*hight/4
input_dim = 32
Rad = input_dim/2

conv1_features=64
conv2_features=32
conv3_features=1
c = 0

num_channels_1=1
num_channels_2=64
num_channels_3=32
lr = 1e-3


def plot(samples):
    fig = plt.figure(figsize=(4, 4))
    gs = gridspec.GridSpec(4, 4)
    gs.update(wspace=0.05, hspace=0.05)

    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(width, hight), cmap='Greys_r')

    return fig


def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev)


# =============================== Q(z|X) ======================================

# X = tf.placeholder(tf.float32, shape=[None, X_dim])
z = tf.placeholder(tf.float32, shape=[None, z_dim])
x_input_shape = (mb_size, width, hight, num_channels_1)
X = tf.placeholder(tf.float32, shape=x_input_shape)

# conv1_weight = tf.Variable(tf.truncated_normal([4, 4, num_channels, conv1_features],
#                                                stddev=0.1, dtype=tf.float32))
# conv1_bias = tf.Variable(tf.zeros([conv1_features], dtype=tf.float32))

Q_W1 = tf.Variable(xavier_init([X_dim, h_dim]))
Q_b1 = tf.Variable(tf.zeros(shape=[h_dim]))

Q_W2_mu = tf.Variable(xavier_init([h_dim, z_dim]))
Q_b2_mu = tf.Variable(tf.zeros(shape=[z_dim]))

Q_W2_sigma = tf.Variable(xavier_init([h_dim, z_dim]))
Q_b2_sigma = tf.Variable(tf.zeros(shape=[z_dim]))


def Q(X):
#     conv1 = tf.nn.conv2d(X, conv1_weight, strides=[1, 1, 1, 1], padding='SAME')
#     h1 = tf.nn.relu(tf.nn.bias_add(conv1, conv1_bias))
#     h1 = tf.reshape(h1,[mb_size,X_dim])
    
    h = tf.nn.relu(tf.matmul(tf.reshape(X,[mb_size,X_dim]), Q_W1) + Q_b1)
    z_mu = tf.matmul(h, Q_W2_mu) + Q_b2_mu
    z_logvar = tf.matmul(h, Q_W2_sigma) + Q_b2_sigma
    return z_mu, z_logvar

def sample_z(mu, log_var):
    eps = tf.random_normal(shape=tf.shape(mu))
    return mu + tf.exp(log_var / 2) * eps

# =============================== P(X|z) ======================================
def P(z):
    h1 = tf.nn.relu(tf.matmul(z, P_W1) + P_b1)
    h2 = tf.nn.relu(tf.add(tf.nn.conv2d_transpose(tf.reshape(h1,[mb_size, width/4, hight/4, 1]), 
                                                  deconv1_weight, strides=[1, 2, 2, 1], padding='SAME',
                                       output_shape=[mb_size, width/2, hight/2, conv1_features]),deconv1_bias))
#     h2 = build_unpool(h2_conv, [1, 2, 2, 1])
    
    h3 = tf.nn.relu(tf.add(tf.nn.conv2d_transpose(tf.reshape(h2,[mb_size, width/2, hight/2, conv1_features]), 
                                                  deconv2_weight, strides=[1, 2, 2, 1], padding='SAME',
                                       output_shape=[mb_size, width/1, hight/1, conv2_features]),deconv2_bias))
    
    h4 = (tf.add(tf.nn.conv2d_transpose(tf.reshape(h3,[mb_size, width/1, hight/1, conv2_features]), 
                                                  deconv3_weight, strides=[1, 1, 1, 1], padding='SAME',
                                       output_shape=[mb_size, width/1, hight/1, conv3_features]),deconv3_bias))
    
    prob = tf.nn.tanh(h4)
    return prob


P_W1 = tf.Variable(xavier_init([z_dim, h_dim]))
P_b1 = tf.Variable(tf.zeros(shape=[h_dim]))

# P_W2 = tf.Variable(xavier_init([h_dim, X_dim]))
# P_b2 = tf.Variable(tf.zeros(shape=[X_dim]))

deconv1_weight = tf.Variable(tf.truncated_normal([4, 4, conv1_features, num_channels_1],
                                               stddev=0.1, dtype=tf.float32))
deconv1_bias = tf.Variable(tf.zeros([conv1_features], dtype=tf.float32))

deconv2_weight = tf.Variable(tf.truncated_normal([4, 4, conv2_features,num_channels_2],
                                               stddev=0.1, dtype=tf.float32))
deconv2_bias = tf.Variable(tf.zeros([conv2_features], dtype=tf.float32))

deconv3_weight = tf.Variable(tf.truncated_normal([4, 4, conv3_features, num_channels_3],
                                               stddev=0.1, dtype=tf.float32))
deconv3_bias = tf.Variable(tf.zeros([conv3_features], dtype=tf.float32))


# =============================== TRAINING ====================================

z_mu, z_logvar = Q(X)
z_sample = sample_z(z_mu, z_logvar)
prob = P(z_sample)

# Sampling from random z
X_samples = P(z)
combination_image=tf.reshape(X_samples[0],[1,height,width,1])
############# white noise ############
conv_out1 = conv2d(combination_image, W_conv1, stride=1, padding='SAME')
conv_out1 = tf.nn.sigmoid(conv_out1)
conv_out1 = max_pool(conv_out1, k_size=2, stride=2, padding="SAME")

############# style image ############
conv_out1_S = conv2d(style_image, W_conv1, stride=1, padding='SAME')
conv_out1_S = tf.nn.sigmoid(conv_out1_S)
conv_out1_S = max_pool(conv_out1_S, k_size=2, stride=2, padding="SAME")

sl1 = style_loss(conv_out1[0,:,:,:], conv_out1_S[0,:,:,:])

# point correlation loss
# PC_ori=correlation_fun(X, input_dim=input_dim, Rad=Rad)
# PC_rec=correlation_fun(prob, input_dim=input_dim, Rad=Rad)
# PC_ran=correlation_fun(X_samples,input_dim=input_dim, Rad=Rad)

# PC_loss1=tf.abs(PC_ori-PC_rec)
# PC_loss2=tf.abs(PC_ori-PC_ran)

# E[log P(X|z)]
recon_loss = tf.reduce_mean(tf.reduce_sum(tf.square((tf.reshape(prob,[mb_size, X_dim])-
                                                     tf.reshape(X,[mb_size, X_dim]))), 1))/4
# D_KL(Q(z|X) || P(z|X)); calculate in closed form as both dist. are Gaussian
kl_loss =tf.reduce_mean(0.5 * tf.reduce_sum(tf.exp(z_logvar) + z_mu**2 - 1. - z_logvar, 1))



# VAE loss
vae_loss = tf.reduce_mean(recon_loss + kl_loss)
tot_loss = tf.reduce_mean(recon_loss + kl_loss + sl1)

solver = tf.train.AdamOptimizer().minimize(vae_loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

if not os.path.exists('out/'):
    os.makedirs('out/')

i = 0
PC_ori=[]
saver = tf.train.Saver()

for it in range(20000):
    X_mb = images[(it*10)%100:(it*10)%100+mb_size]
#     PC_ori = tf.reduce_mean(tf.concat([PC_ori, PC_ori_temp],0))
    
#     print((it*10)%100,(it*10)%100+mb_size)
    _, loss, recon_E, kl_E = sess.run([solver, vae_loss, recon_loss, kl_loss], 
                                                    feed_dict={X: X_mb.reshape(mb_size, width, hight, num_channels_1),
                                                              z: np.random.randn(mb_size, z_dim)})

    if it % 500 == 0:
        print('Iter: {}'.format(it))
        print('Loss: {}'.format(loss))
        print('recon_E:{}'.format(recon_E))
        print('kl_E:{}'.format(kl_E))
        
        print()

        samples = sess.run(X_samples, feed_dict={z: np.random.randn(mb_size, z_dim)})

#         fig = plot(samples)
#         plt.savefig('out/{}.png'.format(str(i).zfill(3)), bbox_inches='tight')
#         i += 1
#         plt.close(fig)
save_path = saver.save(sess, "/tmp/model.ckpt")
# Out:
# Iter: 0
# Loss: 299.718811035
# recon_E:273.048706055
# kl_E:26.6701087952
# ()
# Iter: 250
# Loss: 233.138595581
# recon_E:229.382736206
# kl_E:3.75585842133
# ()
# Iter: 500
# Loss: 228.509078979
# recon_E:222.712493896
# kl_E:5.79657936096
# ()
# Iter: 750
# Loss: 227.981918335
# recon_E:219.64906311
# kl_E:8.33286190033
# ()
# Iter: 1000
# Loss: 214.437042236
# recon_E:203.210525513
# kl_E:11.2265224457
# ()
# Iter: 1250
# Loss: 210.22543335
# recon_E:197.849609375
# kl_E:12.3758268356
# ()
# Iter: 1500
# Loss: 202.829223633
# recon_E:188.637451172
# kl_E:14.1917734146
# ()
# Iter: 1750
# Loss: 200.813995361
# recon_E:184.021438599
# kl_E:16.7925643921
# ()
# Iter: 2000
# Loss: 195.709472656
# recon_E:178.44644165
# kl_E:17.2630271912
# ()
# Iter: 2250
# Loss: 192.397079468
# recon_E:173.118728638
# kl_E:19.2783508301
# ()
# Iter: 2500
# Loss: 185.084625244
# recon_E:165.43939209
# kl_E:19.645236969
# ()
# Iter: 2750
# Loss: 182.558868408
# recon_E:161.039489746
# kl_E:21.5193786621
# ()
# Iter: 3000
# Loss: 176.277313232
# recon_E:154.749221802
# kl_E:21.5280838013
# ()
# Iter: 3250
# Loss: 176.869812012
# recon_E:152.755508423
# kl_E:24.1143112183
# ()
# Iter: 3500
# Loss: 174.272674561
# recon_E:150.685028076
# kl_E:23.5876502991
# ()
# Iter: 3750
# Loss: 165.997879028
# recon_E:141.159225464
# kl_E:24.8386573792
# ()
# Iter: 4000
# Loss: 158.801651001
# recon_E:134.283935547
# kl_E:24.5177154541
# ()
# Iter: 4250
# Loss: 162.492416382
# recon_E:136.715316772
# kl_E:25.7771053314
# ()
# Iter: 4500
# Loss: 153.852035522
# recon_E:127.519004822
# kl_E:26.3330345154
# ()
# Iter: 4750
# Loss: 153.062088013
# recon_E:125.812896729
# kl_E:27.2491893768
# ()
# Iter: 5000
# Loss: 152.516876221
# recon_E:125.48223114
# kl_E:27.0346431732
# ()
# /home/p2admin/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Iter: 5250
# Loss: 142.308456421
# recon_E:115.266860962
# kl_E:27.0415973663
# ()
# Iter: 5500
# Loss: 142.642379761
# recon_E:115.05557251
# kl_E:27.5868110657
# ()
# Iter: 5750
# Loss: 135.969772339
# recon_E:107.68888855
# kl_E:28.280878067
# ()
# Iter: 6000
# Loss: 143.938949585
# recon_E:114.613647461
# kl_E:29.325302124
# ()
# Iter: 6250
# Loss: 138.250091553
# recon_E:109.687469482
# kl_E:28.5626239777
# ()
# Iter: 6500
# Loss: 131.551391602
# recon_E:102.728424072
# kl_E:28.8229675293
# ()
# Iter: 6750
# Loss: 131.979949951
# recon_E:103.383743286
# kl_E:28.5962123871
# ()
# Iter: 7000
# Loss: 131.086578369
# recon_E:102.900054932
# kl_E:28.1865234375
# ()
# Iter: 7250
# Loss: 127.215545654
# recon_E:98.6718902588
# kl_E:28.5436553955
# ()
# Iter: 7500
# Loss: 131.998352051
# recon_E:102.259742737
# kl_E:29.7386131287
# ()
# Iter: 7750
# Loss: 122.583137512
# recon_E:92.3994750977
# kl_E:30.1836605072
# ()
# Iter: 8000
# Loss: 133.276992798
# recon_E:104.458526611
# kl_E:28.8184623718
# ()
# Iter: 8250
# Loss: 122.551780701
# recon_E:94.008430481
# kl_E:28.5433521271
# ()
# Iter: 8500
# Loss: 126.036880493
# recon_E:95.6641693115
# kl_E:30.372713089
# ()
# Iter: 8750
# Loss: 121.912498474
# recon_E:91.8966522217
# kl_E:30.0158481598
# ()
# Iter: 9000
# Loss: 121.806243896
# recon_E:92.0903778076
# kl_E:29.7158699036
# ()
# Iter: 9250
# Loss: 118.485404968
# recon_E:89.3848114014
# kl_E:29.1005954742
# ()
# Iter: 9500
# Loss: 113.756072998
# recon_E:83.217666626
# kl_E:30.5384082794
# ()
# Iter: 9750
# Loss: 112.112731934
# recon_E:81.6276550293
# kl_E:30.4850749969
# ()
# Iter: 10000
# Loss: 113.368606567
# recon_E:83.3412017822
# kl_E:30.0274009705
# ()
# Iter: 10250
# Loss: 111.460662842
# recon_E:80.7923278809
# kl_E:30.6683330536
# ()
# Iter: 10500
# Loss: 109.185501099
# recon_E:78.9111022949
# kl_E:30.274394989
# ()
# Iter: 10750
# Loss: 109.948196411
# recon_E:80.1478805542
# kl_E:29.8003196716
# ()
# Iter: 11000
# Loss: 113.018043518
# recon_E:81.3633575439
# kl_E:31.6546840668
# ()

# %%
def plot(samples):
    fig = plt.figure(figsize=(10, 10))
    gs = gridspec.GridSpec(1, 5)
    gs.update(wspace=0.05, hspace=0.05)

    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(32, 32), cmap='Greys_r')

X_mb=images[0:mb_size]
z_temp=sess.run(z_mu, feed_dict={X:X_mb.reshape(mb_size, width, hight, num_channels_1)})
# %matplotlib inline
sample_temp=sess.run(X_samples, feed_dict={z: z_temp[0:mb_size]})
# plot_new(sample_temp)
plot(sample_temp)

# %%
def plot(samples):
    fig = plt.figure(figsize=(10, 10))
    gs = gridspec.GridSpec(1, 5)
    gs.update(wspace=0.05, hspace=0.05)

    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(32, 32), cmap='Greys_r')

#     return fig
samples = sess.run(X_samples, feed_dict={z: np.random.randn(mb_size, z_dim)})
sample_sort=samples.reshape(-1)
# sample_sort.sort()
# samples[samples>=(np.sort(sample_sort))[300]]=1
# samples[samples<(np.sort(sample_sort))[300]]=-1
plot(samples)

# %%
def correlation_fun_test(xx,input_dim,Rad):
    sum_store=[]
    for ii in range(len(xx)):
        x = xx[ii]
        point_corr=0
#     if Rad <=50:
        for i in range(input_dim):
            for j in range(input_dim):
                point_corr_temp1=(x[i,j]*x[i,np.mod(j+Rad,input_dim)])
                point_corr=point_corr_temp1+point_corr

        for i in range(input_dim):
            for j in range(input_dim):
                point_corr_temp2=x[i,j]*x[np.mod(i+Rad,input_dim),j]
                point_corr=(point_corr_temp2+point_corr)
        sum_store.append((point_corr+2*input_dim**2)/4.)
#     print(point_corr)
    return sum_store

# %%
S2 = np.zeros([2*mb_size,17])
for i in range(2):
    samples=sess.run(X_samples, feed_dict={z: np.random.randn(mb_size, z_dim)})
    for j in range(17):
        S2[i*mb_size:(i+1)*mb_size,j] = correlation_fun_test(xx=samples,input_dim=32,Rad=j)
#     plt.hist(samples.reshape(-1))

S2_ori = np.zeros([2*mb_size,17])
for i in range(2):
    for j in range(17):
        sample_ori=images[i*mb_size:(i+1)*mb_size].reshape(mb_size,32,32,1)
        S2_ori[i*mb_size:(i+1)*mb_size,j] = correlation_fun_test(xx=sample_ori,input_dim=32,Rad=j)

# %%
import seaborn as sns
# %matplotlib inline
x = np.linspace(0, 16, 17)
sns.tsplot(data=S2)
sns.tsplot(data=S2_ori)

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt
# %matplotlib inline

n = 32  # how many digits we will display
plt.figure(figsize=(10, 4))
for i in range(n):
    # display original
    ax = plt.subplot(4, n/4, i + 1)
    plt.imshow(W3[:,:,:,i].reshape(4, 4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import scipy.io as sio
import time
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras import backend
from keras.models import Model
from keras.applications.vgg16 import VGG16

from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import tensorflow as tf
height=48
width =48
########### autoencoder
W1 = np.array(sio.loadmat('weights_AE/W1_AE.mat')['weights_1'],dtype='float32')
W1[:,:,:,2]=0;W1[:,:,:,21]=0
W1[:,:,:,6]=0;W1[:,:,:,16]=0
# W1[:,:,:,1:24]=0
W2 = np.array(sio.loadmat('weights_AE/W2_AE.mat')['weights_2'],dtype='float32')
W2[:,:,:,9]=0;W2[:,:,:,23]=0
W3 = np.array(sio.loadmat('weights_AE/W3_AE.mat')['weights_3'],dtype='float32')

bias1=np.array(sio.loadmat('weights_AE/bias1_AE.mat')['biases_1'],dtype='float32')
bias2=np.array(sio.loadmat('weights_AE/bias2_AE.mat')['biases_2'],dtype='float32')
bias3=np.array(sio.loadmat('weights_AE/bias3_AE.mat')['biases_3'],dtype='float32')

########### RBM

# # # W1 = np.array(sio.loadmat('weights_RBM/W1_RBM.mat')['W1'],dtype='float32')
# W1 = np.array(sio.loadmat('W1_Ti.mat')['W1'],dtype='float32')
# W2 = np.array(sio.loadmat('W2_Ti.mat')['W2'],dtype='float32')
# W3 = np.array(sio.loadmat('W3_Ti.mat')['W3'],dtype='float32')

# # # bias1=np.array(sio.loadmat('weights_RBM/bias1_RBM.mat')['hbias_vec'],dtype='float32')
# bias1=np.array(sio.loadmat('bias1_Ti.mat')['bias1'],dtype='float32')
# bias2=np.array(sio.loadmat('bias2_Ti.mat')['bias2'],dtype='float32')
# bias3=np.array(sio.loadmat('bias3_Ti.mat')['bias3'],dtype='float32')

# W1 = np.array(sio.loadmat('W1_Ti.mat')['W1'],dtype='float32')

# bias1=np.array(sio.loadmat('weights_RBM/bias1_RBM.mat')['hbias_vec'],dtype='float32')
# bias1=np.array(sio.loadmat('bias1_Ti.mat')['bias1'],dtype='float32')

images = np.array(sio.loadmat('WB_test64_GAN_sm.mat')['WB_sm'],dtype='float32')
style_img = np.array(sio.loadmat('WB_sm.mat')['WB_sm'],dtype='float32')
content_img = np.array(sio.loadmat('content_img/test_sample.mat')['sample'],dtype='float32')


# images = np.array(sio.loadmat('WB.mat')['WB'],dtype='float32')
# images[images==0]=-1

# style_img=images[0].reshape(1,height,width,1)
content_img=content_img.reshape(1,128,128,1)
style_img=style_img[1].reshape(1,100,100,1)
plt.imshow(style_img.reshape(100,100),'gray')
# Out:
# Using TensorFlow backend.

# %%
W1.shape
# Out:
# (6, 6, 1, 24)

# %%
# content_img = np.array(sio.loadmat('test_sample.mat')['sample'],dtype='float32')
# content_img = content_img.reshape(1,128,128,1)
# plt.imshow(content_img.reshape(128,128),'gray')

# content_img = style_img.reshape(1,100,100,1)
plt.imshow(content_img.reshape(128,128),'gray')

# %%
# style_image = backend.variable(style_img)
# content_image = backend.variable(content_img)
# combination_image = backend.placeholder((1, height, width, 1))

style_image = tf.placeholder(tf.float32, shape=(1,100,100,1))
content_image=tf.placeholder(tf.float32, shape=(1,128,128,1))
combination_image=tf.Variable(tf.random_uniform((1,128,128,1),0,1))

# %%
def conv2d(x, W, stride, padding="SAME"):
    return tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding=padding)
    
def max_pool(x, k_size, stride, padding="VALID"):
    # use avg pooling instead, as described in the paper
    return tf.nn.avg_pool(x, ksize=[1, k_size, k_size, 1],
                          strides=[1, stride, stride, 1], padding=padding)    

def gram_matrix(x):
    features = backend.batch_flatten(backend.permute_dimensions(x, (2, 0, 1)))
#     features_mean,features_var =tf.nn.moments(features,axes=[0])    
    features_mean = tf.reduce_mean(features,0)
#     features = (features-features_mean)
    gram = backend.dot(features, backend.transpose(features))
#     D=tf.sqrt(tf.diag(tf.diag_part(gram)))
#     Q=tf.matmul(tf.matmul(tf.matrix_inverse(D),gram),tf.matrix_inverse(D))

#     return (gram-tf.reduce_min(tf.reshape(gram,[-1])))/(tf.reduce_max(tf.reshape(gram,[-1]))-tf.reduce_min(tf.reshape(gram,[-1]))) 
#     gram_dig = tf.diag_part(gram)   
    return gram
    
def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 1
    size = height * width
    return backend.sum(backend.square(S - C))/ 1

# %%
import tensorflow as tf
W_conv1 = tf.reshape(tf.constant(W1),[6,6,1,24])
W_conv2 = tf.reshape(tf.constant(W2),[9,9,24,40])
W_conv3 = tf.reshape(tf.constant(W3),[9,9,40,288])

b_conv1 = tf.reshape(tf.constant(bias1),[-1])
b_conv2 = tf.reshape(tf.constant(bias2),[-1])
b_conv3 = tf.reshape(tf.constant(bias3),[-1])
############# white noise ############
conv_out1 = conv2d(combination_image, W_conv1, stride=1, padding='SAME')
conv_out1 = tf.nn.bias_add(conv_out1, b_conv1)
conv_out1 = tf.nn.relu(conv_out1)
conv_out1 = max_pool(conv_out1, k_size=2, stride=2, padding="SAME")

conv_out2 = conv2d(conv_out1, W_conv2, stride=1, padding='SAME')
conv_out2 = tf.nn.bias_add(conv_out2, b_conv2)
conv_out2 = tf.nn.relu(conv_out2)
conv_out2 = max_pool(conv_out2, k_size=2, stride=2, padding="SAME")

conv_out3 = conv2d(conv_out2, W_conv3, stride=1, padding='SAME')
conv_out3 = tf.nn.bias_add(conv_out3, b_conv3)
conv_out3 = tf.nn.relu(conv_out3)

############# style image ############
conv_out1_S = conv2d(style_image, W_conv1, stride=1, padding='SAME')
conv_out1_S = tf.nn.bias_add(conv_out1_S, b_conv1)
conv_out1_S = tf.nn.relu(conv_out1_S)
conv_out1_S = max_pool(conv_out1_S, k_size=2, stride=2, padding="SAME")

conv_out2_S = conv2d(conv_out1_S, W_conv2, stride=1, padding='SAME')
conv_out2_S = tf.nn.bias_add(conv_out2_S, b_conv2)
conv_out2_S = tf.nn.relu(conv_out2_S)
conv_out2_S = max_pool(conv_out2_S, k_size=2, stride=2, padding="SAME")

conv_out3_S = conv2d(conv_out2_S, W_conv3, stride=1, padding='SAME')
conv_out3_S = tf.nn.bias_add(conv_out3_S, b_conv3)
conv_out3_S = tf.nn.relu(conv_out3_S)

############# content image ############
conv_out1_C = conv2d(content_image, W_conv1, stride=1, padding='SAME')
conv_out1_C = tf.nn.bias_add(conv_out1_C, b_conv1)
conv_out1_C = tf.nn.relu(conv_out1_C)
conv_out1_C = max_pool(conv_out1_C, k_size=2, stride=2, padding="SAME")

conv_out2_C = conv2d(conv_out1_C, W_conv2, stride=1, padding='SAME')
conv_out2_C = tf.nn.bias_add(conv_out2_C, b_conv2)
conv_out2_C = tf.nn.relu(conv_out2_C)
conv_out2_C = max_pool(conv_out2_C, k_size=2, stride=2, padding="SAME")

conv_out3_C = conv2d(conv_out2_C, W_conv3, stride=1, padding='SAME')
conv_out3_C = tf.nn.bias_add(conv_out3_C, b_conv3)
conv_out3_C = tf.nn.relu(conv_out3_C)

# %%
def content_loss(content, combination):
    return backend.sum(backend.square(combination - content))

content_image_features = conv_out1_C
combination_features = conv_out1

cl = content_loss(content_image_features,combination_features)

# %%
# loss = backend.variable(0.)

sl1 = style_loss(conv_out1[0,:,:,:], conv_out1_S[0,:,:,:])
sl2 = style_loss(conv_out2[0,:,:,:], conv_out2_S[0,:,:,:])
sl3 = style_loss(conv_out3[0,:,:,:], conv_out3_S[0,:,:,:])


# gram_test1 =gram_matrix(conv_out1[0,:,:,:])
# gram_test2 =gram_matrix(conv_out2[0,:,:,:])
# gram_test3 =gram_matrix(conv_out3[0,:,:,:])
# gram_test1S=gram_matrix(conv_out1_S[0,:,:,:])
# gram_test2S=gram_matrix(conv_out2_S[0,:,:,:])
# gram_test3S=gram_matrix(conv_out3_S[0,:,:,:])
# loss = sl1 + cl

# grads = backend.gradients(loss, combination_image)

# def total_variation_loss(x):
#     a = backend.square(x[:, :height-1, :width-1, :] - x[:, 1:, :width-1, :])
#     b = backend.square(x[:, :height-1, :width-1, :] - x[:, :height-1, 1:, :])
#     return backend.sum(backend.pow(a + b, 1.25))

# vl = total_variation_loss(combination_image)*10000

# %%
loss =sl1#+sl2*1#+sl3*1

solver0 = tf.train.AdamOptimizer(learning_rate=1e-1).minimize(loss)
solver1 = tf.train.AdamOptimizer(learning_rate=1e-2).minimize(loss)
solver2 = tf.train.AdamOptimizer(learning_rate=1e-3).minimize(loss)
solver3 = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(loss)
sess = tf.Session()
sess.run(tf.global_variables_initializer())

it=60000
for i in range(100):
    _, loss1 = sess.run([solver1, loss], feed_dict={content_image: content_img,
                                                  style_image: style_img})
#     _, loss1 = sess.run([solver2, loss], feed_dict={style_image: style_img})

#     solver.run()
    print('Iteration %d/%d' % (i + 1, it))

    if (i%5 == 0):
#         loss1 = loss.eval()
        print('    total loss: %g' % loss1)
# Out:
# Iteration 1/60000
#     total loss: 1942.03
# Iteration 2/60000
# Iteration 3/60000
# Iteration 4/60000
# Iteration 5/60000
# Iteration 6/60000
#     total loss: 1413.2
# Iteration 7/60000
# Iteration 8/60000
# Iteration 9/60000
# Iteration 10/60000
# Iteration 11/60000
#     total loss: 926.955
# Iteration 12/60000
# Iteration 13/60000
# Iteration 14/60000
# Iteration 15/60000
# Iteration 16/60000
#     total loss: 542.926
# Iteration 17/60000
# Iteration 18/60000
# Iteration 19/60000
# Iteration 20/60000
# Iteration 21/60000
#     total loss: 296.982
# Iteration 22/60000
# Iteration 23/60000
# Iteration 24/60000
# Iteration 25/60000
# Iteration 26/60000
#     total loss: 173.347
# Iteration 27/60000
# Iteration 28/60000
# Iteration 29/60000
# Iteration 30/60000
# Iteration 31/60000
#     total loss: 123.679
# Iteration 32/60000
# Iteration 33/60000
# Iteration 34/60000
# Iteration 35/60000
# Iteration 36/60000
#     total loss: 88.7767
# Iteration 37/60000
# Iteration 38/60000
# Iteration 39/60000
# Iteration 40/60000
# Iteration 41/60000
#     total loss: 61.4283
# Iteration 42/60000
# Iteration 43/60000
# Iteration 44/60000
# Iteration 45/60000
# Iteration 46/60000
#     total loss: 47.7508
# Iteration 47/60000
# Iteration 48/60000
# Iteration 49/60000
# Iteration 50/60000
# Iteration 51/60000
#     total loss: 38.0396
# Iteration 52/60000
# Iteration 53/60000
# Iteration 54/60000
# Iteration 55/60000
# Iteration 56/60000
#     total loss: 29.2722
# Iteration 57/60000
# Iteration 58/60000
# Iteration 59/60000
# Iteration 60/60000
# Iteration 61/60000
#     total loss: 23.9699
# Iteration 62/60000
# Iteration 63/60000
# Iteration 64/60000
# Iteration 65/60000
# Iteration 66/60000
#     total loss: 20.4741
# Iteration 67/60000
# Iteration 68/60000
# Iteration 69/60000
# Iteration 70/60000
# Iteration 71/60000
#     total loss: 17.2504
# Iteration 72/60000
# Iteration 73/60000
# Iteration 74/60000
# Iteration 75/60000
# Iteration 76/60000
#     total loss: 14.7196
# Iteration 77/60000
# Iteration 78/60000
# Iteration 79/60000
# Iteration 80/60000
# Iteration 81/60000
#     total loss: 12.8613
# Iteration 82/60000
# Iteration 83/60000
# Iteration 84/60000
# Iteration 85/60000
# Iteration 86/60000
#     total loss: 11.2381
# Iteration 87/60000
# Iteration 88/60000
# Iteration 89/60000
# Iteration 90/60000
# Iteration 91/60000
#     total loss: 9.90886
# Iteration 92/60000
# Iteration 93/60000
# Iteration 94/60000
# Iteration 95/60000
# Iteration 96/60000
#     total loss: 8.82137
# Iteration 97/60000
# Iteration 98/60000
# Iteration 99/60000
# Iteration 100/60000

# %%
for i in range(10000):
    _, loss1 = sess.run([solver2, loss], feed_dict={content_image: content_img,
                                                  style_image: style_img})
#     solver.run()
    print('Iteration %d/%d' % (i + 1, 4000))

    if (i%5 == 0):
#         loss1 = loss.eval()
        print('    total loss: %g' % loss1)
# Out:
# Iteration 1/4000
#     total loss: 1.7081e+06
# Iteration 2/4000
# Iteration 3/4000
# Iteration 4/4000
# Iteration 5/4000
# Iteration 6/4000
#     total loss: 1.70802e+06
# Iteration 7/4000
# Iteration 8/4000
# Iteration 9/4000
# Iteration 10/4000
# Iteration 11/4000
#     total loss: 1.70794e+06
# Iteration 12/4000
# Iteration 13/4000
# Iteration 14/4000
# Iteration 15/4000
# Iteration 16/4000
#     total loss: 1.70786e+06
# Iteration 17/4000
# Iteration 18/4000
# Iteration 19/4000
# Iteration 20/4000
# Iteration 21/4000
#     total loss: 1.70778e+06
# Iteration 22/4000
# Iteration 23/4000
# Iteration 24/4000
# Iteration 25/4000
# Iteration 26/4000
#     total loss: 1.7077e+06
# Iteration 27/4000
# Iteration 28/4000
# Iteration 29/4000
# Iteration 30/4000
# Iteration 31/4000
#     total loss: 1.70762e+06
# Iteration 32/4000
# Iteration 33/4000
# Iteration 34/4000
# Iteration 35/4000
# Iteration 36/4000
#     total loss: 1.70754e+06
# Iteration 37/4000
# Iteration 38/4000
# Iteration 39/4000
# Iteration 40/4000
# Iteration 41/4000
#     total loss: 1.70746e+06
# Iteration 42/4000
# Iteration 43/4000
# Iteration 44/4000
# Iteration 45/4000
# Iteration 46/4000
#     total loss: 1.70739e+06
# Iteration 47/4000
# Iteration 48/4000
# Iteration 49/4000
# Iteration 50/4000
# Iteration 51/4000
#     total loss: 1.70731e+06
# Iteration 52/4000
# Iteration 53/4000
# Iteration 54/4000
# Iteration 55/4000
# Iteration 56/4000
#     total loss: 1.70723e+06
# Iteration 57/4000
# Iteration 58/4000
# Iteration 59/4000
# Iteration 60/4000
# Iteration 61/4000
#     total loss: 1.70715e+06
# Iteration 62/4000
# Iteration 63/4000
# Iteration 64/4000
# Iteration 65/4000
# Iteration 66/4000
#     total loss: 1.70707e+06
# Iteration 67/4000
# Iteration 68/4000
# Iteration 69/4000
# Iteration 70/4000
# Iteration 71/4000
#     total loss: 1.70699e+06
# Iteration 72/4000
# Iteration 73/4000
# Iteration 74/4000
# Iteration 75/4000
# Iteration 76/4000
#     total loss: 1.70691e+06
# Iteration 77/4000
# Iteration 78/4000
# Iteration 79/4000
# Iteration 80/4000
# Iteration 81/4000
#     total loss: 1.70684e+06
# Iteration 82/4000
# Iteration 83/4000
# Iteration 84/4000
# Iteration 85/4000
# Iteration 86/4000
#     total loss: 1.70676e+06
# Iteration 87/4000
# Iteration 88/4000
# Iteration 89/4000
# Iteration 90/4000
# Iteration 91/4000
#     total loss: 1.70668e+06
# Iteration 92/4000
# Iteration 93/4000
# Iteration 94/4000
# Iteration 95/4000
# Iteration 96/4000
#     total loss: 1.7066e+06
# Iteration 97/4000
# Iteration 98/4000
# Iteration 99/4000
# Iteration 100/4000
# Iteration 101/4000
#     total loss: 1.70653e+06
# Iteration 102/4000
# Iteration 103/4000
# Iteration 104/4000
# Iteration 105/4000
# Iteration 106/4000
#     total loss: 1.70645e+06
# Iteration 107/4000
# Iteration 108/4000
# Iteration 109/4000
# Iteration 110/4000
# Iteration 111/4000
#     total loss: 1.70637e+06
# Iteration 112/4000
# Iteration 113/4000
# Iteration 114/4000
# Iteration 115/4000
# Iteration 116/4000
#     total loss: 1.70629e+06
# Iteration 117/4000
# Iteration 118/4000
# Iteration 119/4000
# Iteration 120/4000
# Iteration 121/4000
#     total loss: 1.70622e+06
# Iteration 122/4000
# Iteration 123/4000
# Iteration 124/4000
# Iteration 125/4000
# Iteration 126/4000
#     total loss: 1.70614e+06
# Iteration 127/4000
# Iteration 128/4000
# Iteration 129/4000
# Iteration 130/4000
# Iteration 131/4000
#     total loss: 1.70606e+06
# Iteration 132/4000
# Iteration 133/4000
# Iteration 134/4000
# Iteration 135/4000
# Iteration 136/4000
#     total loss: 1.70599e+06
# Iteration 137/4000
# Iteration 138/4000
# Iteration 139/4000
# Iteration 140/4000
# Iteration 141/4000
#     total loss: 1.70591e+06
# Iteration 142/4000
# Iteration 143/4000
# Iteration 144/4000
# Iteration 145/4000
# Iteration 146/4000
#     total loss: 1.70584e+06
# Iteration 147/4000
# Iteration 148/4000
# Iteration 149/4000
# Iteration 150/4000
# Iteration 151/4000
#     total loss: 1.70576e+06
# Iteration 152/4000
# Iteration 153/4000
# Iteration 154/4000
# Iteration 155/4000
# Iteration 156/4000
#     total loss: 1.70568e+06
# Iteration 157/4000
# Iteration 158/4000
# Iteration 159/4000
# Iteration 160/4000
# Iteration 161/4000
#     total loss: 1.70561e+06
# Iteration 162/4000
# Iteration 163/4000
# Iteration 164/4000
# Iteration 165/4000
# Iteration 166/4000
#     total loss: 1.70553e+06
# Iteration 167/4000
# Iteration 168/4000
# Iteration 169/4000
# Iteration 170/4000
# Iteration 171/4000
#     total loss: 1.70545e+06
# Iteration 172/4000
# Iteration 173/4000
# Iteration 174/4000
# Iteration 175/4000
# Iteration 176/4000
#     total loss: 1.70538e+06
# Iteration 177/4000
# Iteration 178/4000
# Iteration 179/4000
# Iteration 180/4000
# Iteration 181/4000
#     total loss: 1.7053e+06
# Iteration 182/4000
# Iteration 183/4000
# Iteration 184/4000
# Iteration 185/4000
# Iteration 186/4000
#     total loss: 1.70523e+06
# Iteration 187/4000
# Iteration 188/4000
# Iteration 189/4000
# Iteration 190/4000
# Iteration 191/4000
#     total loss: 1.70515e+06
# Iteration 192/4000
# Iteration 193/4000
# Iteration 194/4000
# Iteration 195/4000
# Iteration 196/4000
#     total loss: 1.70507e+06
# Iteration 197/4000
# Iteration 198/4000
# Iteration 199/4000
# Iteration 200/4000
# Iteration 201/4000
#     total loss: 1.705e+06
# Iteration 202/4000
# Iteration 203/4000
# Iteration 204/4000
# Iteration 205/4000
# Iteration 206/4000
#     total loss: 1.70493e+06
# Iteration 207/4000
# Iteration 208/4000
# Iteration 209/4000
# Iteration 210/4000
# Iteration 211/4000
#     total loss: 1.70485e+06
# Iteration 212/4000
# Iteration 213/4000
# Iteration 214/4000
# Iteration 215/4000
# Iteration 216/4000
#     total loss: 1.70477e+06
# Iteration 217/4000
# Iteration 218/4000
# Iteration 219/4000
# Iteration 220/4000
# Iteration 221/4000
#     total loss: 1.7047e+06
# Iteration 222/4000
# Iteration 223/4000
# Iteration 224/4000
# Iteration 225/4000
# Iteration 226/4000
#     total loss: 1.70462e+06
# Iteration 227/4000
# Iteration 228/4000
# Iteration 229/4000
# Iteration 230/4000
# Iteration 231/4000
#     total loss: 1.70455e+06
# Iteration 232/4000
# Iteration 233/4000
# Iteration 234/4000
# Iteration 235/4000
# Iteration 236/4000
#     total loss: 1.70447e+06
# Iteration 237/4000
# Iteration 238/4000
# Iteration 239/4000
# Iteration 240/4000
# Iteration 241/4000
#     total loss: 1.7044e+06
# Iteration 242/4000
# Iteration 243/4000
# Iteration 244/4000
# Iteration 245/4000
# Iteration 246/4000
#     total loss: 1.70432e+06
# Iteration 247/4000
# Iteration 248/4000
# Iteration 249/4000
# Iteration 250/4000
# Iteration 251/4000
#     total loss: 1.70425e+06
# Iteration 252/4000
# Iteration 253/4000
# Iteration 254/4000
# Iteration 255/4000
# Iteration 256/4000
#     total loss: 1.70417e+06
# Iteration 257/4000
# Iteration 258/4000
# Iteration 259/4000
# Iteration 260/4000
# Iteration 261/4000
#     total loss: 1.7041e+06
# Iteration 262/4000
# Iteration 263/4000
# Iteration 264/4000
# Iteration 265/4000
# Iteration 266/4000
#     total loss: 1.70403e+06
# Iteration 267/4000
# Iteration 268/4000
# Iteration 269/4000
# Iteration 270/4000
# Iteration 271/4000
#     total loss: 1.70395e+06
# Iteration 272/4000
# Iteration 273/4000
# Iteration 274/4000
# Iteration 275/4000
# Iteration 276/4000
#     total loss: 1.70388e+06
# Iteration 277/4000
# Iteration 278/4000
# Iteration 279/4000
# Iteration 280/4000
# Iteration 281/4000
#     total loss: 1.7038e+06
# Iteration 282/4000
# Iteration 283/4000
# Iteration 284/4000
# Iteration 285/4000
# Iteration 286/4000
#     total loss: 1.70373e+06
# Iteration 287/4000
# Iteration 288/4000
# Iteration 289/4000
# Iteration 290/4000
# Iteration 291/4000
#     total loss: 1.70365e+06
# Iteration 292/4000
# Iteration 293/4000
# Iteration 294/4000
# Iteration 295/4000
# Iteration 296/4000
#     total loss: 1.70358e+06
# Iteration 297/4000
# Iteration 298/4000
# Iteration 299/4000
# Iteration 300/4000
# Iteration 301/4000
#     total loss: 1.70351e+06
# Iteration 302/4000
# Iteration 303/4000
# Iteration 304/4000
# Iteration 305/4000
# Iteration 306/4000
#     total loss: 1.70343e+06
# Iteration 307/4000
# Iteration 308/4000
# Iteration 309/4000
# Iteration 310/4000
# Iteration 311/4000
#     total loss: 1.70336e+06
# Iteration 312/4000
# Iteration 313/4000
# Iteration 314/4000
# Iteration 315/4000
# Iteration 316/4000
#     total loss: 1.70328e+06
# Iteration 317/4000
# Iteration 318/4000
# Iteration 319/4000
# Iteration 320/4000
# Iteration 321/4000
#     total loss: 1.70321e+06
# Iteration 322/4000
# Iteration 323/4000
# Iteration 324/4000
# Iteration 325/4000
# Iteration 326/4000
#     total loss: 1.70314e+06
# Iteration 327/4000
# Iteration 328/4000
# Iteration 329/4000
# Iteration 330/4000
# Iteration 331/4000
#     total loss: 1.70306e+06
# Iteration 332/4000
# Iteration 333/4000
# Iteration 334/4000
# Iteration 335/4000
# Iteration 336/4000
#     total loss: 1.70299e+06
# Iteration 337/4000
# Iteration 338/4000
# Iteration 339/4000
# Iteration 340/4000
# Iteration 341/4000
#     total loss: 1.70292e+06
# Iteration 342/4000
# Iteration 343/4000
# Iteration 344/4000
# Iteration 345/4000
# Iteration 346/4000
#     total loss: 1.70284e+06
# Iteration 347/4000
# Iteration 348/4000
# Iteration 349/4000
# Iteration 350/4000
# Iteration 351/4000
#     total loss: 1.70277e+06
# Iteration 352/4000
# Iteration 353/4000
# Iteration 354/4000
# Iteration 355/4000
# Iteration 356/4000
#     total loss: 1.7027e+06
# Iteration 357/4000
# Iteration 358/4000
# Iteration 359/4000
# Iteration 360/4000
# Iteration 361/4000
#     total loss: 1.70262e+06
# Iteration 362/4000
# Iteration 363/4000
# Iteration 364/4000
# Iteration 365/4000
# Iteration 366/4000
#     total loss: 1.70255e+06
# Iteration 367/4000
# Iteration 368/4000
# Iteration 369/4000
# Iteration 370/4000
# Iteration 371/4000
#     total loss: 1.70248e+06
# Iteration 372/4000
# Iteration 373/4000
# Iteration 374/4000
# Iteration 375/4000
# Iteration 376/4000
#     total loss: 1.7024e+06
# Iteration 377/4000
# Iteration 378/4000
# Iteration 379/4000
# Iteration 380/4000
# Iteration 381/4000
#     total loss: 1.70233e+06
# Iteration 382/4000
# Iteration 383/4000
# Iteration 384/4000
# Iteration 385/4000
# Iteration 386/4000
#     total loss: 1.70226e+06
# Iteration 387/4000
# Iteration 388/4000
# Iteration 389/4000
# Iteration 390/4000
# Iteration 391/4000
#     total loss: 1.70219e+06
# Iteration 392/4000
# Iteration 393/4000
# Iteration 394/4000
# Iteration 395/4000
# Iteration 396/4000
#     total loss: 1.70211e+06
# Iteration 397/4000
# Iteration 398/4000
# Iteration 399/4000
# Iteration 400/4000
# Iteration 401/4000
#     total loss: 1.70204e+06
# Iteration 402/4000
# Iteration 403/4000
# Iteration 404/4000
# Iteration 405/4000
# Iteration 406/4000
#     total loss: 1.70197e+06
# Iteration 407/4000
# Iteration 408/4000
# Iteration 409/4000
# Iteration 410/4000
# Iteration 411/4000
#     total loss: 1.70189e+06
# Iteration 412/4000
# Iteration 413/4000
# Iteration 414/4000
# Iteration 415/4000
# Iteration 416/4000
#     total loss: 1.70182e+06
# Iteration 417/4000
# Iteration 418/4000
# Iteration 419/4000
# Iteration 420/4000
# Iteration 421/4000
#     total loss: 1.70175e+06
# Iteration 422/4000
# Iteration 423/4000
# Iteration 424/4000
# Iteration 425/4000
# Iteration 426/4000
#     total loss: 1.70167e+06
# Iteration 427/4000
# Iteration 428/4000
# Iteration 429/4000
# Iteration 430/4000
# Iteration 431/4000
#     total loss: 1.7016e+06
# Iteration 432/4000
# Iteration 433/4000
# Iteration 434/4000
# Iteration 435/4000
# Iteration 436/4000
#     total loss: 1.70153e+06
# Iteration 437/4000
# Iteration 438/4000
# Iteration 439/4000
# Iteration 440/4000
# Iteration 441/4000
#     total loss: 1.70146e+06
# Iteration 442/4000
# Iteration 443/4000
# Iteration 444/4000
# Iteration 445/4000
# Iteration 446/4000
#     total loss: 1.70138e+06
# Iteration 447/4000
# Iteration 448/4000
# Iteration 449/4000
# Iteration 450/4000
# Iteration 451/4000
#     total loss: 1.70131e+06
# Iteration 452/4000
# Iteration 453/4000
# Iteration 454/4000
# Iteration 455/4000
# Iteration 456/4000
#     total loss: 1.70124e+06
# Iteration 457/4000
# Iteration 458/4000
# Iteration 459/4000
# Iteration 460/4000
# Iteration 461/4000
#     total loss: 1.70117e+06
# Iteration 462/4000
# Iteration 463/4000
# Iteration 464/4000
# Iteration 465/4000
# Iteration 466/4000
#     total loss: 1.7011e+06
# Iteration 467/4000
# Iteration 468/4000
# Iteration 469/4000
# Iteration 470/4000
# Iteration 471/4000
#     total loss: 1.70102e+06
# Iteration 472/4000
# Iteration 473/4000
# Iteration 474/4000
# Iteration 475/4000
# Iteration 476/4000
#     total loss: 1.70095e+06
# Iteration 477/4000
# Iteration 478/4000
# Iteration 479/4000
# Iteration 480/4000
# Iteration 481/4000
#     total loss: 1.70088e+06
# Iteration 482/4000
# Iteration 483/4000
# Iteration 484/4000
# Iteration 485/4000
# Iteration 486/4000
#     total loss: 1.70081e+06
# Iteration 487/4000
# Iteration 488/4000
# Iteration 489/4000
# Iteration 490/4000
# Iteration 491/4000
#     total loss: 1.70074e+06
# Iteration 492/4000
# Iteration 493/4000
# Iteration 494/4000
# Iteration 495/4000
# Iteration 496/4000
#     total loss: 1.70066e+06
# Iteration 497/4000
# Iteration 498/4000
# Iteration 499/4000
# Iteration 500/4000
# Iteration 501/4000
#     total loss: 1.70059e+06
# Iteration 502/4000
# Iteration 503/4000
# Iteration 504/4000
# Iteration 505/4000
# Iteration 506/4000
#     total loss: 1.70052e+06
# Iteration 507/4000
# Iteration 508/4000
# Iteration 509/4000
# Iteration 510/4000
# Iteration 511/4000
#     total loss: 1.70045e+06
# Iteration 512/4000
# Iteration 513/4000
# Iteration 514/4000
# Iteration 515/4000
# Iteration 516/4000
#     total loss: 1.70038e+06
# Iteration 517/4000
# Iteration 518/4000
# Iteration 519/4000
# Iteration 520/4000
# Iteration 521/4000
#     total loss: 1.7003e+06
# Iteration 522/4000
# Iteration 523/4000
# Iteration 524/4000
# Iteration 525/4000
# Iteration 526/4000
#     total loss: 1.70023e+06
# Iteration 527/4000
# Iteration 528/4000
# Iteration 529/4000
# Iteration 530/4000
# Iteration 531/4000
#     total loss: 1.70016e+06
# Iteration 532/4000
# Iteration 533/4000
# Iteration 534/4000
# Iteration 535/4000
# Iteration 536/4000
#     total loss: 1.70009e+06
# Iteration 537/4000
# Iteration 538/4000
# Iteration 539/4000
# Iteration 540/4000
# Iteration 541/4000
#     total loss: 1.70002e+06
# Iteration 542/4000
# Iteration 543/4000
# Iteration 544/4000
# Iteration 545/4000
# Iteration 546/4000
#     total loss: 1.69994e+06
# Iteration 547/4000
# Iteration 548/4000
# Iteration 549/4000
# Iteration 550/4000
# Iteration 551/4000
#     total loss: 1.69987e+06
# Iteration 552/4000
# Iteration 553/4000
# Iteration 554/4000
# Iteration 555/4000
# Iteration 556/4000
#     total loss: 1.6998e+06
# Iteration 557/4000
# Iteration 558/4000
# Iteration 559/4000
# Iteration 560/4000
# Iteration 561/4000
#     total loss: 1.69973e+06
# Iteration 562/4000
# Iteration 563/4000
# Iteration 564/4000
# Iteration 565/4000
# Iteration 566/4000
#     total loss: 1.69966e+06
# Iteration 567/4000
# Iteration 568/4000
# Iteration 569/4000
# Iteration 570/4000
# Iteration 571/4000
#     total loss: 1.69959e+06
# Iteration 572/4000
# Iteration 573/4000
# Iteration 574/4000
# Iteration 575/4000
# Iteration 576/4000
#     total loss: 1.69952e+06
# Iteration 577/4000
# Iteration 578/4000
# Iteration 579/4000
# Iteration 580/4000
# Iteration 581/4000
#     total loss: 1.69945e+06
# Iteration 582/4000
# Iteration 583/4000
# Iteration 584/4000
# Iteration 585/4000
# Iteration 586/4000
#     total loss: 1.69937e+06
# Iteration 587/4000
# Iteration 588/4000
# Iteration 589/4000
# Iteration 590/4000
# Iteration 591/4000
#     total loss: 1.6993e+06
# Iteration 592/4000
# Iteration 593/4000
# Iteration 594/4000
# Iteration 595/4000
# Iteration 596/4000
#     total loss: 1.69923e+06
# Iteration 597/4000
# Iteration 598/4000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-456db17681e8> in <module>()
#       1 for i in range(10000):
#       2     _, loss1 = sess.run([solver2, loss], feed_dict={content_image: content_img,
# ----> 3                                                   style_image: style_img})
#       4 #     solver.run()
#       5     print('Iteration %d/%d' % (i + 1, 4000))
#
# /home/p2admin/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/p2admin/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/p2admin/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/p2admin/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/p2admin/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
test1=sess.run(combination_image)
print test1.shape
plt.hist(test1.reshape(-1))
# Out:
# (1, 128, 128, 1)
# (array([   65.,   998.,  1318.,  1515.,  3103.,  4763.,  3257.,  1161.,
#           194.,    10.]),
#  array([-0.47003442, -0.26128628, -0.05253813,  0.15621001,  0.36495816,
#          0.5737063 ,  0.78245444,  0.99120259,  1.19995073,  1.40869887,
#          1.61744702]),
#  <a list of 10 Patch objects>)

# %%
# import seaborn
plt.imshow(test1.reshape(128,128),'gray')
plt.grid(False)

# %%
test1=sess.run(conv_out1_S, feed_dict={content_image: content_img,style_image: style_img})
plt.hist(test1.reshape(-1))
print test1.shape
# Out:
# (1, 50, 50, 24)

# %%
test1=sess.run(conv_out1, feed_dict={content_image: content_img,style_image: style_img})
plt.hist(test1.reshape(-1))
print test1.shape

fig, axs = plt.subplots(4,6, figsize=(12,12), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for i in range(24):

    axs[i].imshow(test1[:,:,:,i].reshape(64,64),'gray')
    plt.grid(False)
# Out:
# (1, 64, 64, 24)

# %%
# sns.heatmap(test1.reshape(64*64,24))
# sns.heatmap(test1[:,:,:,0].reshape(50,50))

fig, axs = plt.subplots(4,6, figsize=(12,12), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for i in range(24):

    axs[i].imshow(test1[:,:,:,i].reshape(50,50),'gray')
    plt.grid(False)

# %%
test1=sess.run(conv_out2_S, feed_dict={content_image: content_img,style_image: style_img})
# plt.hist(test1.reshape(-1))
print test1.shape
# Out:
# (1, 25, 25, 40)

# %%
fig, axs = plt.subplots(5,8, figsize=(8, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for i in range(40):

    axs[i].imshow(test1[:,:,:,i].reshape(25,25),'gray')
    plt.grid(False)

# %%
test1=sess.run(conv_out3_S, feed_dict={content_image: content_img,style_image: style_img})
# plt.hist(test1.reshape(-1))
print test1.shape

fig, axs = plt.subplots(16,18, figsize=(8, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for i in range(288):

    axs[i].imshow(test1[:,:,:,i].reshape(25,25),'gray')
    plt.grid(False)
# Out:
# (1, 25, 25, 288)

# %%
E1,E2,E3,E1S,E2S,E3S = sess.run([gram_test1,gram_test2,gram_test3, gram_test1S,gram_test2S,gram_test3S], feed_dict={content_image: content_img,
                                              style_image: style_img})
import seaborn as sns
sns.heatmap(E3S)

# %%
test2=sess.run(conv_out1, feed_dict={content_image: content_img,style_image: style_img})
plt.hist(test2.reshape(-1))
print test1.shape
# Out:
# (1, 24, 24, 24)

# %%
E1,E2,E3,E4 = sess.run([gram_test1,gram_test2,gram_test1S,gram_test2S], feed_dict={content_image: content_img,
                                              style_image: style_img})
import seaborn as sns
sns.heatmap(E3)

# %%
np.mean(np.square(E1-E3))
# Out:
# 0.019924536

# %%
a = [[1, 0], [0, 1]]
b = [[4, 1], [2, 2]]
np.dot(a,b)
# Out:
# array([[4, 1],
#        [2, 2]])

# %%
from numpy.linalg import inv
test1_mean=np.mean(test1.reshape(24*24,24),axis=1)
test1_mean=test1.reshape(24*24,24)-test1_mean.reshape(576,1)
test1_cov=np.dot(test1_mean.reshape(24*24,24).T,test1_mean.reshape(24*24,24))
test_diag=np.sqrt(np.diag(np.diag(test1_cov)))
test1_norm=np.matmul(np.matmul(inv(test_diag),test1_cov),inv(test_diag))
import seaborn as sns
sns.heatmap(test1_norm)
# print test1_norm

# %%
test1_cov=np.dot(test2.reshape(24*24,24).T,test2.reshape(24*24,24))
test1_norm=(test1_cov-np.mean(test1_cov,axis=0))/np.std(test1_cov,axis=0)
import seaborn as sns
sns.heatmap(test1_norm)
# print test1_norm

# %%
np.mean(np.square(test2-test1))
# Out:
# 0.03815547

# %%
test1=sess.run(b_conv1)
plt.hist(test1.reshape(-1))
print test1.shape
# Out:
# (24,)

# %%
W2_test=sess.run(W_conv2, feed_dict={content_image: content_img,style_image: style_img})
plt.hist(W2_test.reshape(-1))
# Out:
# (array([  4.60000000e+01,   6.52000000e+02,   5.57200000e+03,
#           3.50000000e+04,   2.76410000e+04,   6.80400000e+03,
#           1.54900000e+03,   3.85000000e+02,   1.01000000e+02,
#           1.00000000e+01]),
#  array([-2.17018247, -1.64833369, -1.12648492, -0.60463614, -0.08278737,
#          0.4390614 ,  0.96091018,  1.48275895,  2.00460773,  2.5264565 ,
#          3.04830527]),
#  <a list of 10 Patch objects>)

# %%
test1

# %%
outputs = [loss]
outputs += grads
f_outputs = backend.function([combination_image], outputs)

def eval_loss_and_grads(x):
    x = x.reshape((1, height, width, 1))
    outs = f_outputs([x])
    loss_value = outs[0]
    grad_values = outs[1].flatten().astype('float64')
    return loss_value, grad_values

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
x = np.random.uniform(-1, 1, (1, height, width, 1))

iterations = 100

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# ('Start of iteration', 0)
# ('Current loss value:', 161532.69)
# Iteration 0 completed in 1s
# ('Start of iteration', 1)
# ('Current loss value:', 33240.461)
# Iteration 1 completed in 0s
# ('Start of iteration', 2)
# ('Current loss value:', 12829.632)
# Iteration 2 completed in 0s
# ('Start of iteration', 3)
# ('Current loss value:', 7217.2236)
# Iteration 3 completed in 0s
# ('Start of iteration', 4)
# ('Current loss value:', 4870.9707)
# Iteration 4 completed in 0s
# ('Start of iteration', 5)
# ('Current loss value:', 3543.3757)
# Iteration 5 completed in 0s
# ('Start of iteration', 6)
# ('Current loss value:', 2712.8042)
# Iteration 6 completed in 0s
# ('Start of iteration', 7)
# ('Current loss value:', 2181.7959)
# Iteration 7 completed in 0s
# ('Start of iteration', 8)
# ('Current loss value:', 1745.8237)
# Iteration 8 completed in 0s
# ('Start of iteration', 9)
# ('Current loss value:', 1437.484)
# Iteration 9 completed in 0s
# ('Start of iteration', 10)
# ('Current loss value:', 1225.6289)
# Iteration 10 completed in 0s
# ('Start of iteration', 11)
# ('Current loss value:', 987.30927)
# Iteration 11 completed in 0s
# ('Start of iteration', 12)
# ('Current loss value:', 853.06567)
# Iteration 12 completed in 0s
# ('Start of iteration', 13)
# ('Current loss value:', 743.45184)
# Iteration 13 completed in 0s
# ('Start of iteration', 14)
# ('Current loss value:', 663.19006)
# Iteration 14 completed in 0s
# ('Start of iteration', 15)
# ('Current loss value:', 614.50293)
# Iteration 15 completed in 0s
# ('Start of iteration', 16)
# ('Current loss value:', 569.35486)
# Iteration 16 completed in 0s
# ('Start of iteration', 17)
# ('Current loss value:', 530.28339)
# Iteration 17 completed in 0s
# ('Start of iteration', 18)
# ('Current loss value:', 494.08853)
# Iteration 18 completed in 0s
# ('Start of iteration', 19)
# ('Current loss value:', 461.24829)
# Iteration 19 completed in 0s
# ('Start of iteration', 20)
# ('Current loss value:', 436.19769)
# Iteration 20 completed in 0s
# ('Start of iteration', 21)
# ('Current loss value:', 413.71194)
# Iteration 21 completed in 0s
# ('Start of iteration', 22)
# ('Current loss value:', 391.47144)
# Iteration 22 completed in 0s
# ('Start of iteration', 23)
# ('Current loss value:', 370.38589)
# Iteration 23 completed in 0s
# ('Start of iteration', 24)
# ('Current loss value:', 351.43381)
# Iteration 24 completed in 0s
# ('Start of iteration', 25)
# ('Current loss value:', 336.22659)
# Iteration 25 completed in 0s
# ('Start of iteration', 26)
# ('Current loss value:', 322.81714)
# Iteration 26 completed in 0s
# ('Start of iteration', 27)
# ('Current loss value:', 310.57257)
# Iteration 27 completed in 0s
# ('Start of iteration', 28)
# ('Current loss value:', 298.0929)
# Iteration 28 completed in 0s
# ('Start of iteration', 29)
# ('Current loss value:', 288.19208)
# Iteration 29 completed in 0s
# ('Start of iteration', 30)
# ('Current loss value:', 278.82825)
# Iteration 30 completed in 0s
# ('Start of iteration', 31)
# ('Current loss value:', 269.79904)
# Iteration 31 completed in 0s
# ('Start of iteration', 32)
# ('Current loss value:', 260.24869)
# Iteration 32 completed in 0s
# ('Start of iteration', 33)
# ('Current loss value:', 251.20442)
# Iteration 33 completed in 0s
# ('Start of iteration', 34)
# ('Current loss value:', 242.29987)
# Iteration 34 completed in 0s
# ('Start of iteration', 35)
# ('Current loss value:', 234.4677)
# Iteration 35 completed in 0s
# ('Start of iteration', 36)
# ('Current loss value:', 226.82611)
# Iteration 36 completed in 0s
# ('Start of iteration', 37)
# ('Current loss value:', 219.21292)
# Iteration 37 completed in 0s
# ('Start of iteration', 38)
# ('Current loss value:', 210.67465)
# Iteration 38 completed in 0s
# ('Start of iteration', 39)
# ('Current loss value:', 202.74368)
# Iteration 39 completed in 0s
# ('Start of iteration', 40)
# ('Current loss value:', 193.97348)
# Iteration 40 completed in 0s
# ('Start of iteration', 41)
# ('Current loss value:', 186.83952)
# Iteration 41 completed in 0s
# ('Start of iteration', 42)
# ('Current loss value:', 179.9285)
# Iteration 42 completed in 0s
# ('Start of iteration', 43)
# ('Current loss value:', 173.49606)
# Iteration 43 completed in 0s
# ('Start of iteration', 44)
# ('Current loss value:', 169.76907)
# Iteration 44 completed in 0s
# ('Start of iteration', 45)
# ('Current loss value:', 166.35324)
# Iteration 45 completed in 0s
# ('Start of iteration', 46)
# ('Current loss value:', 162.72552)
# Iteration 46 completed in 0s
# ('Start of iteration', 47)
# ('Current loss value:', 158.84256)
# Iteration 47 completed in 0s
# ('Start of iteration', 48)
# ('Current loss value:', 155.659)
# Iteration 48 completed in 0s
# ('Start of iteration', 49)
# ('Current loss value:', 152.00519)
# Iteration 49 completed in 0s
# ('Start of iteration', 50)
# ('Current loss value:', 149.29181)
# Iteration 50 completed in 0s
# ('Start of iteration', 51)
# ('Current loss value:', 146.60526)
# Iteration 51 completed in 0s
# ('Start of iteration', 52)
# ('Current loss value:', 144.62701)
# Iteration 52 completed in 0s
# ('Start of iteration', 53)
# ('Current loss value:', 142.09578)
# Iteration 53 completed in 0s
# ('Start of iteration', 54)
# ('Current loss value:', 139.68936)
# Iteration 54 completed in 0s
# ('Start of iteration', 55)
# ('Current loss value:', 137.94429)
# Iteration 55 completed in 0s
# ('Start of iteration', 56)
# ('Current loss value:', 135.98183)
# Iteration 56 completed in 0s
# ('Start of iteration', 57)
# ('Current loss value:', 134.21353)
# Iteration 57 completed in 0s
# ('Start of iteration', 58)
# ('Current loss value:', 132.65292)
# Iteration 58 completed in 0s
# ('Start of iteration', 59)
# ('Current loss value:', 131.1019)
# Iteration 59 completed in 0s
# ('Start of iteration', 60)
# ('Current loss value:', 129.42319)
# Iteration 60 completed in 0s
# ('Start of iteration', 61)
# ('Current loss value:', 128.0885)
# Iteration 61 completed in 0s
# ('Start of iteration', 62)
# ('Current loss value:', 126.51773)
# Iteration 62 completed in 0s
# ('Start of iteration', 63)
# ('Current loss value:', 125.15665)
# Iteration 63 completed in 0s
# ('Start of iteration', 64)
# ('Current loss value:', 123.209)
# Iteration 64 completed in 0s
# ('Start of iteration', 65)
# ('Current loss value:', 121.67351)
# Iteration 65 completed in 0s
# ('Start of iteration', 66)
# ('Current loss value:', 119.64825)
# Iteration 66 completed in 0s
# ('Start of iteration', 67)
# ('Current loss value:', 118.17116)
# Iteration 67 completed in 0s
# ('Start of iteration', 68)
# ('Current loss value:', 117.02507)
# Iteration 68 completed in 0s
# ('Start of iteration', 69)
# ('Current loss value:', 115.99164)
# Iteration 69 completed in 0s
# ('Start of iteration', 70)
# ('Current loss value:', 114.68372)
# Iteration 70 completed in 0s
# ('Start of iteration', 71)
# ('Current loss value:', 113.44061)
# Iteration 71 completed in 0s
# ('Start of iteration', 72)
# ('Current loss value:', 111.41264)
# Iteration 72 completed in 0s
# ('Start of iteration', 73)
# ('Current loss value:', 109.64552)
# Iteration 73 completed in 0s
# ('Start of iteration', 74)
# ('Current loss value:', 108.53897)
# Iteration 74 completed in 0s
# ('Start of iteration', 75)
# ('Current loss value:', 107.51913)
# Iteration 75 completed in 0s
# ('Start of iteration', 76)
# ('Current loss value:', 102.45776)
# Iteration 76 completed in 0s
# ('Start of iteration', 77)
# ('Current loss value:', 98.237701)
# Iteration 77 completed in 0s
# ('Start of iteration', 78)
# ('Current loss value:', 97.309212)
# Iteration 78 completed in 0s
# ('Start of iteration', 79)
# ('Current loss value:', 96.43589)
# Iteration 79 completed in 0s
# ('Start of iteration', 80)
# ('Current loss value:', 95.74881)
# Iteration 80 completed in 0s
# ('Start of iteration', 81)
# ('Current loss value:', 95.112381)
# Iteration 81 completed in 0s
# ('Start of iteration', 82)
# ('Current loss value:', 94.524628)
# Iteration 82 completed in 0s
# ('Start of iteration', 83)
# ('Current loss value:', 93.944672)
# Iteration 83 completed in 0s
# ('Start of iteration', 84)
# ('Current loss value:', 93.429237)
# Iteration 84 completed in 0s
# ('Start of iteration', 85)
# ('Current loss value:', 92.930374)
# Iteration 85 completed in 0s
# ('Start of iteration', 86)
# ('Current loss value:', 92.428123)
# Iteration 86 completed in 0s
# ('Start of iteration', 87)
# ('Current loss value:', 91.929161)
# Iteration 87 completed in 0s
# ('Start of iteration', 88)
# ('Current loss value:', 91.1632)
# Iteration 88 completed in 0s
# ('Start of iteration', 89)
# ('Current loss value:', 90.401024)
# Iteration 89 completed in 0s
# ('Start of iteration', 90)
# ('Current loss value:', 89.634338)
# Iteration 90 completed in 0s
# ('Start of iteration', 91)
# ('Current loss value:', 89.048927)
# Iteration 91 completed in 0s
# ('Start of iteration', 92)
# ('Current loss value:', 88.505798)
# Iteration 92 completed in 0s
# ('Start of iteration', 93)
# ('Current loss value:', 88.095665)
# Iteration 93 completed in 0s
# ('Start of iteration', 94)
# ('Current loss value:', 87.5625)
# Iteration 94 completed in 0s
# ('Start of iteration', 95)
# ('Current loss value:', 87.025772)
# Iteration 95 completed in 0s
# ('Start of iteration', 96)
# ('Current loss value:', 86.441856)
# Iteration 96 completed in 0s
# ('Start of iteration', 97)
# ('Current loss value:', 85.854095)
# Iteration 97 completed in 0s
# ('Start of iteration', 98)
# ('Current loss value:', 85.13147)
# Iteration 98 completed in 0s
# ('Start of iteration', 99)
# ('Current loss value:', 84.43306)
# Iteration 99 completed in 0s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = x.reshape((height, width, 1))
plt.imshow(x.reshape(48,48),'gray')
